# %% [markdown]
# <a href="https://colab.research.google.com/github/14790897/-IQEQ-Tester-GPT4/blob/main/GPT-SoVITS-Colab-WebUI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GPT-SoVITS WebUI

# %% [markdown]
# ## Env Setup (Run Once Only)
# ## 环境配置, 只需运行一次

# %% [markdown]
# ### 1.

# %%
from google.colab import drive
drive.mount('/content/drive')
# %%bash
set -e
cd /content/GPT-SoVITS
CACHE="/content/drive/MyDrive/gpt_sovits_cache"

to_link=(
  "GPT_SoVITS/pretrained_models"
  "GPT_SoVITS/text/G2PWModel"
  "tools/uvr5/uvr5_weights"
  "GPT_weights" "GPT_weights_v2" "GPT_weights_v2Pro" "GPT_weights_v2ProPlus" "GPT_weights_v3" "GPT_weights_v4"
  "SoVITS_weights" "SoVITS_weights_v2" "SoVITS_weights_v2Pro" "SoVITS_weights_v2ProPlus" "SoVITS_weights_v3" "SoVITS_weights_v4"
)

for d in "${to_link[@]}"; do
  if [ -d "$CACHE/$d" ]; then
    mkdir -p "$(dirname "$d")"
    ln -sfn "$CACHE/$d" "$d"
  fi
done

echo "Links restored."

# %%
# %%writefile /content/setup.sh
# set -e
#
# cd /content
#
# git clone https://github.com/RVC-Boss/GPT-SoVITS.git
#
# cd GPT-SoVITS
#
# if conda env list | awk '{print $1}' | grep -Fxq "GPTSoVITS"; then
#     :
# else
#     conda create -n GPTSoVITS python=3.10 -y
# fi
#
# source activate GPTSoVITS
#
# pip install ipykernel
#
# bash install.sh --device CU126 --source HF --download-uvr5
# Out:
# Writing /content/setup.sh

# %% [markdown]
# ### 2.

# %%
# %pip install -q condacolab
import condacolab
condacolab.install_from_url("https://repo.anaconda.com/archive/Anaconda3-2024.10-1-Linux-x86_64.sh")
# !cd /content && bash setup.sh
# Out:
# ⏬ Downloading https://repo.anaconda.com/archive/Anaconda3-2024.10-1-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:01:46
# 🔁 Restarting kernel...
# Cloning into 'GPT-SoVITS'...
# remote: Enumerating objects: 5832, done.
# remote: Counting objects: 100% (29/29), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 5832 (delta 15), reused 4 (delta 4), pack-reused 5803 (from 3)
# Receiving objects: 100% (5832/5832), 14.07 MiB | 15.36 MiB/s, done.
# Resolving deltas: 100% (3342/3342), done.
# Channels:
#  - defaults
# Platform: linux-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/GPTSoVITS
#
#   added / updated specs:
#     - python=3.10
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2025.12.2  |       h06a4308_0         125 KB
# ...

# %% [markdown]
# ## Launch WebUI
# ## 启动 WebUI

# %%
# !cd /content/GPT-SoVITS && source activate GPTSoVITS && export is_share=True && python webui.py
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Running on local URL:  http://0.0.0.0:9874
# Running on public URL: https://a889729013721789f9.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# "/usr/local/envs/GPTSoVITS/bin/python" -s tools/asr/funasr_asr.py -i "/content/00d3ae0ba7689f84.wav" -o "output/asr_opt" -s large -l zh -p float32
# /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages/requests/__init__.py:113: RequestsDependencyWarning: urllib3 (2.6.3) or chardet (6.0.0.post1)/charset_normalizer (3.4.4) doesn't match a supported version!
#   warnings.warn(
# Traceback (most recent call last):
#   File "/content/GPT-SoVITS/tools/asr/funasr_asr.py", line 7, in <module>
#     from funasr import AutoModel
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !cd /content/GPT-SoVITS && ls -lah
# !cd /content/GPT-SoVITS && find . -maxdepth 3 -type d \( -iname "*pretrain*" -o -iname "*uvr5*" -o -iname "*g2pw*" -o -iname "*weights*" \) -print
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# total 360K
# drwxr-xr-x 22 root root 4.0K Feb 27 03:44 .
# drwxr-xr-x  1 root root 4.0K Feb 27 03:16 ..
# -rw-r--r--  1 root root  46K Feb 27 03:16 api.py
# -rw-r--r--  1 root root  22K Feb 27 03:16 api_v2.py
# -rw-r--r--  1 root root 5.0K Feb 27 03:16 Colab-Inference.ipynb
# -rw-r--r--  1 root root 2.7K Feb 27 03:16 Colab-WebUI.ipynb
# -rw-r--r--  1 root root 7.6K Feb 27 03:16 config.py
# drwxr-xr-x  2 root root 4.0K Feb 27 03:16 Docker
# -rw-r--r--  1 root root 1.8K Feb 27 03:16 docker_build.sh
# -rw-r--r--  1 root root 1.9K Feb 27 03:16 docker-compose.yaml
# -rw-r--r--  1 root root 1.6K Feb 27 03:16 Dockerfile
# -rw-r--r--  1 root root 3.7K Feb 27 03:16 .dockerignore
# drwxr-xr-x  7 root root 4.0K Feb 27 03:16 docs
# -rw-r--r--  1 root root   15 Feb 27 03:16 extra-req.txt
# drwxr-xr-x  8 root root 4.0K Feb 27 03:16 .git
# drwxr-xr-x  3 root root 4.0K Feb 27 03:16 .github
# ...

# %%
# !mkdir -p /content/drive/MyDrive/gpt_sovits_cache
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)

# %%
# %%bash
# set -e
# cd /content/GPT-SoVITS
# CACHE="/content/drive/MyDrive/gpt_sovits_cache"
#
# # 这些是你已经列出来存在的关键目录（解压后的模型）
# to_move=(
#   "GPT_SoVITS/pretrained_models"
#   "GPT_SoVITS/text/G2PWModel"
#   "tools/uvr5/uvr5_weights"
#   "GPT_weights" "GPT_weights_v2" "GPT_weights_v2Pro" "GPT_weights_v2ProPlus" "GPT_weights_v2ProPro" "GPT_weights_v3" "GPT_weights_v4"
#   "SoVITS_weights" "SoVITS_weights_v2" "SoVITS_weights_v2Pro" "SoVITS_weights_v2ProPlus" "SoVITS_weights_v3" "SoVITS_weights_v4"
# )
#
# # 有些目录名你仓库里不一定都有，所以逐个判断存在再移动
# for d in "${to_move[@]}"; do
#   if [ -d "$d" ]; then
#     mkdir -p "$CACHE/$(dirname "$d")"
#     mv -n "$d" "$CACHE/$d"
#     echo "moved: $d -> $CACHE/$d"
#   else
#     echo "skip (not exist): $d"
#   fi
# done
#
# echo "Done. Top cache dirs:"
# ls -lah "$CACHE" | head
# Out:
# moved: GPT_SoVITS/pretrained_models -> /content/drive/MyDrive/gpt_sovits_cache/GPT_SoVITS/pretrained_models
# moved: GPT_SoVITS/text/G2PWModel -> /content/drive/MyDrive/gpt_sovits_cache/GPT_SoVITS/text/G2PWModel
# moved: tools/uvr5/uvr5_weights -> /content/drive/MyDrive/gpt_sovits_cache/tools/uvr5/uvr5_weights
# moved: GPT_weights -> /content/drive/MyDrive/gpt_sovits_cache/GPT_weights
# moved: GPT_weights_v2 -> /content/drive/MyDrive/gpt_sovits_cache/GPT_weights_v2
# moved: GPT_weights_v2Pro -> /content/drive/MyDrive/gpt_sovits_cache/GPT_weights_v2Pro
# moved: GPT_weights_v2ProPlus -> /content/drive/MyDrive/gpt_sovits_cache/GPT_weights_v2ProPlus
# skip (not exist): GPT_weights_v2ProPro
# moved: GPT_weights_v3 -> /content/drive/MyDrive/gpt_sovits_cache/GPT_weights_v3
# moved: GPT_weights_v4 -> /content/drive/MyDrive/gpt_sovits_cache/GPT_weights_v4
# moved: SoVITS_weights -> /content/drive/MyDrive/gpt_sovits_cache/SoVITS_weights
# ...

# %%
# %%bash
# set -e
# cd /content/GPT-SoVITS
# CACHE="/content/drive/MyDrive/gpt_sovits_cache"
#
# to_link=(
#   "GPT_SoVITS/pretrained_models"
#   "GPT_SoVITS/text/G2PWModel"
#   "tools/uvr5/uvr5_weights"
#   "GPT_weights" "GPT_weights_v2" "GPT_weights_v2Pro" "GPT_weights_v2ProPlus" "GPT_weights_v3" "GPT_weights_v4"
#   "SoVITS_weights" "SoVITS_weights_v2" "SoVITS_weights_v2Pro" "SoVITS_weights_v2ProPlus" "SoVITS_weights_v3" "SoVITS_weights_v4"
# )
#
# for d in "${to_link[@]}"; do
#   if [ -d "$CACHE/$d" ]; then
#     mkdir -p "$(dirname "$d")"
#     ln -sfn "$CACHE/$d" "$d"
#     echo "linked: $d -> $CACHE/$d"
#   else
#     echo "skip (cache missing): $d"
#   fi
# done
#
# echo "Verify (should point to /content/drive/...):"
# readlink -f GPT_SoVITS/pretrained_models
# readlink -f GPT_SoVITS/text/G2PWModel
# readlink -f tools/uvr5/uvr5_weights
# Out:
# linked: GPT_SoVITS/pretrained_models -> /content/drive/MyDrive/gpt_sovits_cache/GPT_SoVITS/pretrained_models
# linked: GPT_SoVITS/text/G2PWModel -> /content/drive/MyDrive/gpt_sovits_cache/GPT_SoVITS/text/G2PWModel
# linked: tools/uvr5/uvr5_weights -> /content/drive/MyDrive/gpt_sovits_cache/tools/uvr5/uvr5_weights
# linked: GPT_weights -> /content/drive/MyDrive/gpt_sovits_cache/GPT_weights
# linked: GPT_weights_v2 -> /content/drive/MyDrive/gpt_sovits_cache/GPT_weights_v2
# linked: GPT_weights_v2Pro -> /content/drive/MyDrive/gpt_sovits_cache/GPT_weights_v2Pro
# linked: GPT_weights_v2ProPlus -> /content/drive/MyDrive/gpt_sovits_cache/GPT_weights_v2ProPlus
# linked: GPT_weights_v3 -> /content/drive/MyDrive/gpt_sovits_cache/GPT_weights_v3
# linked: GPT_weights_v4 -> /content/drive/MyDrive/gpt_sovits_cache/GPT_weights_v4
# linked: SoVITS_weights -> /content/drive/MyDrive/gpt_sovits_cache/SoVITS_weights
# ...

# %%
# !cd /content/GPT-SoVITS && ls -lah GPT_SoVITS | head -n 30
# !cd /content/GPT-SoVITS && ls -lah tools/uvr5 | head -n 30
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# total 360K
# drwxr-xr-x 12 root root 4.0K Feb 27 03:57 .
# drwxr-xr-x 10 root root 4.0K Feb 27 03:57 ..
# drwxr-xr-x  7 root root 4.0K Feb 27 03:16 AR
# drwxr-xr-x  7 root root 4.0K Feb 27 03:16 BigVGAN
# drwxr-xr-x  2 root root 4.0K Feb 27 03:16 configs
# -rw-r--r--  1 root root  300 Feb 27 03:16 download.py
# drwxr-xr-x  2 root root 4.0K Feb 27 03:16 eres2net
# -rw-r--r--  1 root root  39K Feb 27 03:16 export_torch_script.py
# -rw-r--r--  1 root root  42K Feb 27 03:16 export_torch_script_v3v4.py
# drwxr-xr-x  3 root root 4.0K Feb 27 03:16 f5_tts
# drwxr-xr-x  2 root root 4.0K Feb 27 03:16 feature_extractor
# -rw-r--r--  1 root root 2.7K Feb 27 03:16 inference_cli.py
# -rw-r--r--  1 root root  12K Feb 27 03:16 inference_gui.py
# -rw-r--r--  1 root root  21K Feb 27 03:16 inference_webui_fast.py
# -rw-r--r--  1 root root  49K Feb 27 03:16 inference_webui.py
# ...

# %%
# !cd /content/GPT-SoVITS && readlink -f GPT_SoVITS/pretrained_models
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /content/drive/MyDrive/gpt_sovits_cache/GPT_SoVITS/pretrained_models

# %%
# !du -sh /content/drive/MyDrive/gpt_sovits_cache
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# 5.9G	/content/drive/MyDrive/gpt_sovits_cache
